# %% [markdown]
# # Q.1) Create a string containing your full name. Print the string.

# %%
full_name=("Muhammad Abdullah")

# %%
print(full_name)
# Out:
# Muhammad Abdullah

# %% [markdown]
# # Q.2) Create a string with the sentence of your choice and print its length.

# %%
sentence=("I'm learning Python Programming")

# %%
len(sentence)
# Out:
# 31

# %% [markdown]
# # Q.3) Assign a srting to a variable and check its data type using Python.

# %%
x= 23.2

# %%
type(x)
# Out:
# float

# %% [markdown]
# # Q.4) Create a variable word with the value"Python" and print the first character.

# %%
word="Python"

# %%
print(word[0])
# Out:
# P

# %% [markdown]
# # Q.5) Create a variable  course with the value "Python" and print the character at index 3

# %%
course="Python"

# %%
print(course[3])
# Out:
# h

# %% [markdown]
# # Q.6) Create a variable "framework" with the value"Tensorflow" and print the character at negative index-4.

# %%
framework="Tensorflow"

# %%
print(framework[-4])
# Out:
# f

# %% [markdown]
# # Q.7) Create a variable "fruit" with the value "Apple". Convert the string to uppercase and print it.

# %%
fruit="Apple"

# %%
print(fruit.upper())
# Out:
# APPLE

# %% [markdown]
# # Q.8) Create a variable "city" with the value "Karachi". Convert the string to lowercase and print it.

# %%
city="Karachi"

# %%
print(city.lower())
# Out:
# karachi

# %% [markdown]
# # Q.9) Create a variable" framework" with the value"Django". Check if the string starts with "D" and print the true or false.

# %%
framework="Django"

# %%
print(framework.startswith("D"))
# Out:
# True

# %% [markdown]
# # Q.10) Create a variable "subject" with the value "mathematics". Check if all characters are alphabetic and print true or false.

# %%
subject="mathematics"

# %%
print(subject.isalpha())
# Out:
# True

# %% [markdown]
# # Q.11) Ask the user to enter their email in any format and then convert in into lowercase.

# %%
email= input("Enter your email address: ")
print(email.lower())
# Out:
# Enter your email address:  HafizAbdullah@gmail.com
# hafizabdullah@gmail.com
